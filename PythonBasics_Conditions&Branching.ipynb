# %%
#Python Basics for beginners
#Conditions and Branching

#Method of equality of two variables using double "Equal Sign", ==, as follows
A=3
B=4
print("A=B: ", A==B)
#the ooutput is False

A=3.6
B=3.6
print("A=B: ",A==B)
#the ooutput is True

#We can measure equality of any types of variables, for example, string
Q1="Beh"
Q2="Beh"
print("Q1=Q2: ",Q1==Q2)

# We can also use "lift operand",<, and "right operand",>,to evaluate (GREATER or SMALLER) two variables
# "lift operand",<
zeta=92.36
beta=99.1
print("Zeta < Beta: ",zeta <beta)
print("Beta < Zeta: ",beta <zeta)

# "right operand",>
x1=106.36
beta=99.1
print("x1 < Beta: ",x1 <beta)
print("Beta < x1: ",beta <x1)

#Greater or equal 
azeta=98.36
abeta=98.1
print("aZeta <= aBeta: ",azeta <abeta)
print("aBeta >= aZeta: ",abeta <azeta)

#Inequality 
#For not equal, you can use "Exclamation Mark",!, with "Equal Sign",=, "!=" as follows
A=3
B=4
print("A!=B: ", A!=B)
#the ooutput is False

A=3.6
B=3.6
print("A!=B: ",A!=B)
#the ooutput is True

# %%
#Branching 
#Branching allows us to run different statements for different inputs
age=58
if (age > 55):
    print ("You are pretty old 🧓 ")
print("Move on")

Mass=60
if (age > 78):
    print ("You are pretty fat")
print("Do exercise")


#using else to limit the problem

mark=58

if (mark > 55):
    print ("It is a good product:)")
else:
    print("It is not a good product")
print("Quality is important ")


Mass=60
if (age > 78):
    print ("You are pretty fat")
else:
    print("you are in a goog weight")
    print("Keep doing your sports plan")

# %%
#Using "if", "else", "elif"

mark=67

if (mark > 55):
    print ("It is a good product:)")
elif(mark==55):
    print("the product got 55")
else:
    print("It is not a good product")
print("Quality is important ")

age=50
Mass=60
if (age > 78):
    print ("You are pretty fat")
elif(Mass<40):
    print("you are thin")
    #we can use a number of condition among other conditions 
    if (age<100):
        print("You have a lot of chance to live")
elif(age>40):
    print("you should consume more protein like meats and chickens")
    #we can use a number of condition among other conditions 
    if (age<50):
        print("You are still in the beginning of the path")
else:
    print("you are in a goog weight")
    print("Keep doing your sports plan")

# %%
#logic operations
#"And", "Or", "Not" etc
#The results of operations have been valued by BOOLEAN VALUES, such as True and False
Bit=1100
mark=78
if (mark > 55) or (Bit==1100):
    print ("It is a good product:)")
elif(mark==55) or (Bit==1010):
    print("the product got 55")
else:
    print("It is not a good product")
print("Quality is important ")

age=50
Mass=60
if (age > 78) and (mark>34):
    print ("You are pretty fat")
elif(Mass<40)and (age>20):
    print("you are thin")
    #we can use a number of condition among other conditions 
    if (age<100):
        print("You have a lot of chance to live")
elif(age>40)and (age==35):
    print("you should consume more protein like meats and chickens")
    #we can use a number of condition among other conditions 
    if (age<50):
        print("You are still in the beginning of the path")
else:
    print("you are in a goog weight")
    print("Keep doing your sports plan")
